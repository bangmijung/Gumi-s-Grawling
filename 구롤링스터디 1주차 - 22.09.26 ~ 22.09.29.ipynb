# %% [markdown]
# # 🥕구미의 구롤링 스터디 1주차(환경설정)

# %% [markdown]
# <참고자료>
# https://hleecaster.com/python-web-crawling-with-beautifulsoup/

# %% [markdown]
# ## 00. 자기소개 Time🙆🏻‍♂️🙆🏻‍♀️🙆🏻‍♂️🙆🏻‍♀️

# %% [markdown]
# ### 월요일 분반
# **오재은 - 라타 | 최윤아 - 치코 | 정찬빈 - (찬)밥**
#
# **최준혁 - 에디 | 안형준 - 이든 | <span style="color:blue"> 방미정 - 구미 </span>**
# ### 목요일 분반
# **김재학 - OOO | 최현수 - OOO | 최윤서 - OOO**
#
# **손채현 - OOO | 박찬호 - OOO | <span style="color:blue"> 방미정 - 구미 </span>**
# ### 금요일 분반
# **백미정 - 메이 | 신유정 - OOO | <span style="color:blue"> 방미정 - 구미 </span>**

# %% [markdown]
# ### (Q1) 여러분들이 사용할 닉네임은??
# ### (Q2) 크롤링 스터디에 들어온 이유는??

# %% [markdown]
# ## 01. 크롤링이란 무엇인가??

# %% [markdown]
# **크롤링(Crawling) 인터넷에 있는 정보 중 우리가 원하는 것만 골라서 자동으로 수집해주는 기술**
#
# **크롤링(Crawling) = 파싱(Parsing) = 스크래핑(Scraping) = 스파이더링(Spidering)**
#
# **크롤링의 원리? 우리가 정보를 가져오려는 사이트를 불러와서거기서 원하는 정보를 찾고 그 정보를 가져오게 하는 코드를 작성하면 끝**

# %% [markdown]
# ### 오늘 해볼 것: 서강대학교 위키피디아 살펴보기
# https://en.wikipedia.org/wiki/Sogang_University
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 02. 간단 환경설정 시작~! (request & beautifulsoup)

# %%
#request, BS4, Selenium 설치 되어있는지 확인
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            0.15.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asgiref                            3.5.2
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# ...

# %%
# !pip install requests

import requests
webpage = requests.get("https://en.wikipedia.org/wiki/Sogang_University")
print(webpage.text)
# Out:
# ...
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Sogang University - Wikipedia</title>
# ...

# %% [markdown]
# ### Beautifulsoup
# 뷰티풀 수프(Beautiful Soup)는 HTML과 XML 문서들의 구문을 분석하기 위한 파이썬 패키지이다.
#
# HTML로부터 데이터를 추출하기 위해 사용할 수 있는 파싱된 페이지의 파스 트리를 만드는데, 이는 웹 스크래핑에 유용하다.
#
# ### Beautifulsoup - Document
#
# 시간날 때 읽어보아~!
#
# [Beautiful Soup Documentation — Beautiful Soup 4.9.0 documentation (crummy.com)](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# 영어 어려우면 국문~!
#
# [뷰티플수프 문서 — 뷰티플수프 4.0.0 문서 (crummy.com)](https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/)

# %% [markdown]
# ### test 코드 돌려보기

# %%
#BS4 install
# !pip install beautifulsoup4

# %%
#BS4 test (서강대학교 위키피디아)

import requests
from bs4 import BeautifulSoup

webpage = requests.get("https://en.wikipedia.org/wiki/Sogang_University")
soup = BeautifulSoup(webpage.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Sogang University - Wikipedia</title>
# ...

# %%
# 태그 탐색하기 (span)
# find all -> 리스트 반환
soup.find_all('span')
# Out:
# [<span class="mw-page-title-main">Sogang University</span>,
#  <span style="font-size: 120%;">Sogang University (SU)</span>,
#  <span style="font-size:85%;"><a href="/wiki/Latin" title="Latin">Latin</a></span>,
#  <span class="noprint">; 62 years ago</span>,
#  <span style="display:none"> (<span class="bday dtstart published updated">1960-04-18</span>)</span>,
#  <span class="bday dtstart published updated">1960-04-18</span>,
#  <span class="legend-color" style="background-color: #AF272F; color:white;"> </span>,
#  <span class="legend-color" style="background-color:silver; color:black;"> </span>,
# ...

# %%
# 태그 속성들은 빼고 그 안에 있는 텍스트만 깔끔하게 가져오고 싶다면?
# soup.find_all('span')[0].string
# soup.find_all('span')[0].text

soup.find_all('span')[0].string
# Out:
# 'Sogang University'

# %%
# html 속성 활용하여 찾기
# attrs 파라미터를 지정하면 된다. 딕셔너리 형태로 넣으면 됨(여러개 지정 가능)
# 만약 mw-page-title-main이라는 이름의 class만 긁어오고 싶다면?

soup.find_all(attrs={'class':'mw-page-title-main'})[0].string
# Out:
# 'Sogang University'

# %% [markdown]
# ## 03. 간단 환경설정 시작~! (chromedriver&selenium)

# %% [markdown]
# 📄 Selenium은 웹 브라우저의 자동화를 가능하게 하고 지원하는 다양한 도구와 라이브러리를 포함한 프로젝트이다.
#
# 브라우저와 사용자 간의 상호 작용을 테스트하는 확장 기능, 브라우저 할당 확장을 위한 배포 서버, 모든 주요 웹 브라우저에 적용 가능한 코드를 작성할 수 있는 W3C WebDriver 사양 구현을 위한 인프라를 제공한다.
#
# Selenium의 핵심은 WebDriver로 웹브라우저를 제어하는 것

# %% [markdown]
# ### Document
#
# [https://www.selenium.dev/](https://www.selenium.dev/)
#
# [https://www.selenium.dev/documentation/webdriver/](https://www.selenium.dev/documentation/webdriver/)

# %%
# !pip install selenium

# %% [markdown]
# ### 본인 크롬 버전에 맞는 크롬드라이버 설치
# ![image.png](attachment:image.png)
# **주피터노트북 파일과 동일한 위치에 있어야 정상적으로 사용할 수 있음(혹은 경로설정 필요)**
#
# 다운로드 링크: https://sites.google.com/chromium.org/driver/

# %% [markdown]
# ### 크롬 버전 확인합시다
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### test 코드 돌려보기

# %%
# Selenium import
from selenium import webdriver

# webdriver 설정하기
browser = webdriver.Chrome('chromedriver.exe')
# Out:
# C:\Users\bangm\AppData\Local\Temp/ipykernel_124276/3945290611.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')

# %%
# 서강대 위키피디아 들어가보기
browser.get("https://en.wikipedia.org/wiki/Sogang_University")

# %%
# Selenium 이용해 서강대 로고 클릭해보기
browser.find_element_by_class_name("infobox-image").click()
# Out:
# C:\Users\bangm\AppData\Local\Temp/ipykernel_122636/3002137024.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   browswer.find_element_by_class_name("infobox-image").click()

# %% [markdown]
# # 오늘은 여기까지~~!
